# %%
from ai.nn.basic.mlp import LMLP, MLP

# %reload_ext autoreload
# %autoreload 2
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from ai.nn.basic.mlp import LMLP, MLP
#       3 get_ipython().run_line_magic('reload_ext', 'autoreload')
#       4 get_ipython().run_line_magic('autoreload', '2')
#
# File ~/dev/AI-4-Alan/src/ai/nn/__init__.py:1
# ----> 1 from .basic import MLP, Layer, Neuron
#       3 __all__ = ["Neuron", "Layer", "MLP"]
#
# File ~/dev/AI-4-Alan/src/ai/nn/basic/__init__.py:1
# ----> 1 from .layer import Layer
#       2 from .mlp import MLP
#       3 from .neuron import Neuron
#
# File ~/dev/AI-4-Alan/src/ai/nn/basic/layer/__init__.py:1
# ----> 1 from .layer import Layer, LLayer
#       3 __all__ = ["Layer", "LLayer"]
#
# File ~/dev/AI-4-Alan/src/ai/nn/basic/layer/layer.py:4
#       1 import torch
#       2 from attr import define, field
# ----> 4 from ..neuron.neuron import LNeuron, Neuron
# ...

# %%
model = LMLP(3, [2, 2, 1])
value = model([1, 2, 3])[0]
value.plot()

# %%
value.backward()
value.plot()

# %%
model = MLP(2, [2, 3, 4, 2])
model([1,2])
# Out:
# tensor([-10.3818,  10.8581])
