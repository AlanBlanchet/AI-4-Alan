# %%
from ai.nn.layer import Layer, LLayer

# %reload_ext autoreload
# %autoreload 2

# %%
model = LLayer(3, 1)
out = model([1,2,3])
out[0].plot()

# %%
model = Layer(3,2)
model([1,2,3])
# Out:
# tensor([-1.7112,  0.5853])
